# %% [markdown]
# ### Importação dos dados

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

loja.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# ...

# %% [markdown]
# #1. Análise do faturamento

# %%
import plotly.express as px

receita_bruta_loja1 = loja.Preço.sum()
receita_bruta_loja1
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #1. Loja 1- Faturamento total

# %%
import numpy as np
plt.figure()
vendas_categoria.plot(kind="bar")
plt.title("Faturamento Total por Categoria")
plt.ylabel("Total Faturado")
plt.xlabel("Categoria")
plt.xticks(rotation=45)
plt.show()

np.float64(1488459.06)
# Out:
# np.float64(1488459.06)

# %%
receita_bruta_loja1 = loja.Preço.sum()
receita_bruta_loja1

resumo_faturamento
# Out:
# Resumo do Valor Total Arrecadado:
# Loja 1: R$1534509.12
# Loja 2: R$1488459.06
# Loja 3: R$1464025.03
# Loja 4: R$1384497.58

# %% [markdown]
# #1. Loja 2- Faturamento total

# %%
receita_bruta_loja2 = loja2.Preço.sum()
receita_bruta_loja2
# Out:
# np.float64(1488459.06)

# %% [markdown]
# #1. Loja 3- Faturamento total

# %%
receita_bruta_loja3 = loja3.Preço.sum()
receita_bruta_loja3
# Out:
# np.float64(1464025.03)

# %% [markdown]
# #1. Loja 4- Faturamento total

# %%
receita_bruta_loja4 = loja4.Preço.sum()
receita_bruta_loja4
# Out:
# np.float64(1384497.58)

# %% [markdown]
# # 2. Vendas por Categoria

# %%
loja1['Avaliação da compra'].mean()
# Out:
# np.float64(3.976685036032217)

# %%
loja2['Avaliação da compra'].mean()
# Out:
# np.float64(4.037303942348453)

# %%
loja3['Avaliação da compra'].mean()
# Out:
# np.float64(4.048325561678677)

# %%
loja4['Avaliação da compra'].mean()
# Out:
# np.float64(3.9957591178965224)

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %%
media_avaliacao = df.groupby("Loja")["Avaliação da compra"].mean().sort_values(ascending=False)

media_avaliacao
# Out:
# Loja
# Loja 3    4.048326
# Loja 2    4.037304
# Loja 4    3.995759
# Loja 1    3.976685
# Name: Avaliação da compra, dtype: float64

# %%
plt.figure()
media_avaliacao.plot(kind="bar")
plt.title("Média de Avaliação por Loja")
plt.ylabel("Avaliação Média")
plt.xlabel("Loja")
plt.ylim(0,5)
plt.show()

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %%
produtos_vendidos = df["Produto"].value_counts()

mais_vendido = produtos_vendidos.idxmax()
menos_vendido = produtos_vendidos.idxmin()

print("Produto mais vendido:", mais_vendido)
print("Produto menos vendido:", menos_vendido)

media_avaliacao = df.groupby('Loja')['Avaliação da compra'].mean().sort_values(ascending=False)

print("Média de Avaliação por Loja:")
print(media_avaliacao)

# Gráfico
media_avaliacao.plot(kind='bar')
plt.title('Média de Avaliação por Loja')
plt.ylabel('Avaliação Média')
plt.xlabel('Loja')
plt.ylim(0,5)
plt.show()
# Out:
# Produto mais vendido: Cômoda
# Produto menos vendido: Celular ABXY
# Média de Avaliação por Loja:
# Loja
# Loja 3    4.048326
# Loja 2    4.037304
# Loja 4    3.995759
# Loja 1    3.976685
# Name: Avaliação da compra, dtype: float64

# %%
plt.figure()
produtos_vendidos.head(10).plot(kind="bar")
plt.title("Top 10 Produtos Mais Vendidos")
plt.ylabel("Quantidade Vendida")
plt.xlabel("Produto")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure()
produtos_vendidos.tail(10).plot(kind="bar")
plt.title("10 Produtos Menos Vendidos")
plt.ylabel("Quantidade Vendida")
plt.xlabel("Produto")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # 5. Frete Médio por Loja

# %%
Frete_media = ({
    "loja-1": 153450912,
    "loja-2" : 148845906,
    "loja-3": 146402503,
    "loja-4": 138449758
})

Frete = pd.Series(Frete_media)
Frete.plot(kind='barh', figsize=(8, 5), color='lightpink')
plt.title('Valor Arrecado Bruto (Em Milhões de Reais)')
plt.xlabel('Total Pago')

Frete_media
# Out:
# {'loja-1': 153450912,
#  'loja-2': 148845906,
#  'loja-3': 146402503,
#  'loja-4': 138449758}

# %%
# visualização dos valores
# loja.groupby("Produto")['Preço'].sum().sort_values()
valor_total_agrupado = loja.groupby([ "Categoria do Produto"])['Preço'].sum().sort_values(ascending=False)
valor_total_agrupado.plot( kind='line',figsize=(16,8), color='red')
# valor_total_agrupado
# Out:
# <Axes: xlabel='Categoria do Produto'>

# %%
loja['Frete'].mean()
# Out:
# np.float64(34.69180491551149)

# %%
print("Média de Frete por Loja:")
print(frete_medio)
# Out:
# Média de Frete por Loja:
# Loja
# Loja 1    34.691805
# Loja 2    33.621941
# Loja 3    33.074464
# Loja 4    31.278997
# Name: Frete, dtype: float64

# %%
plt.figure()
frete_medio.plot(kind="bar")
plt.title("Média de Frete por Loja")
plt.ylabel("Frete Médio")
plt.xlabel("Loja")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # 6. Resultado

# %%
# Diferença entre maior e menor valor em cada indicador
diferencas = {
    "Diferença Média Avaliação": resumo["Media_Avaliacao"].max() - resumo["Media_Avaliacao"].min(),
    "Diferença Total Vendas": resumo["Total_Vendas"].max() - resumo["Total_Vendas"].min(),
    "Diferença Total Frete": resumo["Total_Frete"].max() - resumo["Total_Frete"].min()
}

diferencas
# Out:
# {'Diferença Média Avaliação': 0.07164052564646006,
#  'Diferença Total Vendas': 150011.54000000004,
#  'Diferença Total Frete': 8082.092676708795}
